# %%
import os
from wand.image import Image as WImage
import matplotlib.pyplot as plt
path_to_data='/scratch/spf248/covid/data'
country='ID'
city_name='Jakarta'

# %% [markdown]
# Since early March, we observe a decrease in the number of active users and in their average number of pings. This pattern is probably resulting from the fact that people staying at home in higher number are more rarely using any geolocation services on their phone.

# %% [markdown]
# # 1 - Users Activity

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,'activity-per-day.pdf'))
# Out:
# <wand.image.Image: 44b838a 'PDF' (548x300)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,"share-of-users'-time-spent-at-home.pdf"))
# Out:
# <wand.image.Image: 6db3836 'PDF' (500x300)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,"share-of-users'-staying-home.pdf"))
# Out:
# <wand.image.Image: 7181997 'PDF' (500x300)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,"max.-distance-between-users'-point-of-activity.pdf"))
# Out:
# <wand.image.Image: acb73a0 'PDF' (496x308)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,"share-of-users'-activity-in-unique-neighborhoods.pdf"))
# Out:
# <wand.image.Image: 4de8cf7 'PDF' (500x315)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,"entropy-of-users'-visits-of-neighborhoods.pdf"))
# Out:
# <wand.image.Image: bc0b3c7 'PDF' (496x300)>

# %% [markdown]
# Fig.1: Number of active users over time and average number of pings recorded per users over time.

# %% [markdown]
# # 2 - Differences in behavior across demographic groups

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,'share-of-users-staying-at-home-by-wealth.pdf'))
# Out:
# <wand.image.Image: 9ba81bc 'PDF' (500x293)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,'share-of-users-staying-at-home-by-city.pdf'))
# Out:
# <wand.image.Image: 39d7a9f 'PDF' (500x293)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,'share-of-neighborhoods-visited-by-wealth.pdf'))
# Out:
# <wand.image.Image: 892799b 'PDF' (500x294)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,'share-of-neighborhoods-visited-by-city.pdf'))
# Out:
# <wand.image.Image: 1a836c1 'PDF' (506x293)>

# %% [markdown]
# # 3 - Changes in activity across regions

# %%
WImage(filename=os.path.join(path_to_data,'../fig/activity-change-'+city_name+'.pdf'))
# Out:
# <wand.image.Image: 47ee8a9 'PDF' (684x460)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,'flows-'+city_name+'.pdf'))
# Out:
# <wand.image.Image: acbd4e8 'PDF' (677x539)>

# %%
WImage(filename=os.path.join(path_to_data+'/../fig',country,'flow-changes-'+city_name+'.pdf'))
# Out:
# <wand.image.Image: 8afc338 'PDF' (692x539)>
